# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# Save test ID for submission
test_ID = test["Id"]
train.drop(["Id"], axis=1, inplace=True)
test.drop(["Id"], axis=1, inplace=True)

# %%
for col in train.columns:
    if train[col].dtype == "object":
        fill_value = train[col].mode()[0]          # most frequent category from train
    else:
        fill_value = train[col].median()           # numeric median from train

    # assign back to the DataFrame (avoid inplace on Series)
    train[col] = train[col].fillna(fill_value)
    if col in test.columns:
        test[col] = test[col].fillna(fill_value)

# %%
cat_cols = train.select_dtypes(include=["object"]).columns
le = LabelEncoder()
for col in cat_cols:
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])

# %%
X = train.drop("SalePrice", axis=1)
y = np.log1p(train["SalePrice"])

# %%
cat_model = CatBoostRegressor(
    iterations=5000,
    learning_rate=0.01,
    depth=7,
    l2_leaf_reg=3,
    loss_function="RMSE",
    eval_metric="RMSE",
    random_seed=42,
    verbose=500
)

# %%
cv = KFold(n_splits=10, shuffle=True, random_state=42)
scores = -cross_val_score(cat_model, X, y, scoring="neg_root_mean_squared_error", cv=cv)

print("💡 CatBoost CV RMSE:", np.mean(scores))
# Out:
# 0:	learn: 0.3914716	total: 17.5ms	remaining: 1m 27s
# 500:	learn: 0.1061977	total: 836ms	remaining: 7.51s
# 1000:	learn: 0.0809210	total: 1.65s	remaining: 6.61s
# 1500:	learn: 0.0662770	total: 2.42s	remaining: 5.65s
# 2000:	learn: 0.0550362	total: 3.19s	remaining: 4.78s
# 2500:	learn: 0.0458209	total: 3.96s	remaining: 3.95s
# 3000:	learn: 0.0382634	total: 4.81s	remaining: 3.2s
# 3500:	learn: 0.0321660	total: 5.56s	remaining: 2.38s
# 4000:	learn: 0.0272773	total: 6.33s	remaining: 1.58s
# 4500:	learn: 0.0232190	total: 7.08s	remaining: 785ms
# 4999:	learn: 0.0197896	total: 7.83s	remaining: 0us
# 0:	learn: 0.3939708	total: 2.58ms	remaining: 12.9s
# 500:	learn: 0.1047581	total: 776ms	remaining: 6.97s
# 1000:	learn: 0.0789604	total: 1.56s	remaining: 6.24s
# 1500:	learn: 0.0638494	total: 2.32s	remaining: 5.41s
# 2000:	learn: 0.0524888	total: 3.07s	remaining: 4.6s
# 2500:	learn: 0.0442301	total: 3.83s	remaining: 3.82s
# 3000:	learn: 0.0376054	total: 4.57s	remaining: 3.05s
# 3500:	learn: 0.0321335	total: 5.33s	remaining: 2.28s
# 4000:	learn: 0.0277646	total: 6.1s	remaining: 1.52s
# 4500:	learn: 0.0241459	total: 6.86s	remaining: 761ms
# 4999:	learn: 0.0209901	total: 7.65s	remaining: 0us
# 0:	learn: 0.4001947	total: 1.51ms	remaining: 7.55s
# 500:	learn: 0.1070570	total: 773ms	remaining: 6.94s
# 1000:	learn: 0.0805632	total: 1.54s	remaining: 6.17s
# 1500:	learn: 0.0652578	total: 2.39s	remaining: 5.58s
# 2000:	learn: 0.0539227	total: 3.16s	remaining: 4.74s
# 2500:	learn: 0.0448109	total: 3.9s	remaining: 3.9s
# 3000:	learn: 0.0369570	total: 4.66s	remaining: 3.1s
# 3500:	learn: 0.0310241	total: 5.42s	remaining: 2.32s
# 4000:	learn: 0.0263883	total: 6.17s	remaining: 1.54s
# 4500:	learn: 0.0229157	total: 6.94s	remaining: 769ms
# 4999:	learn: 0.0198439	total: 7.69s	remaining: 0us
# 0:	learn: 0.3942271	total: 2.67ms	remaining: 13.4s
# 500:	learn: 0.1058181	total: 779ms	remaining: 7s
# 1000:	learn: 0.0801049	total: 1.55s	remaining: 6.18s
# 1500:	learn: 0.0658034	total: 2.29s	remaining: 5.34s
# 2000:	learn: 0.0549157	total: 3.1s	remaining: 4.65s
# 2500:	learn: 0.0463459	total: 3.88s	remaining: 3.88s
# 3000:	learn: 0.0392365	total: 4.63s	remaining: 3.08s
# 3500:	learn: 0.0334217	total: 5.39s	remaining: 2.31s
# 4000:	learn: 0.0283916	total: 6.13s	remaining: 1.53s
# 4500:	learn: 0.0244880	total: 6.92s	remaining: 767ms
# 4999:	learn: 0.0211854	total: 7.74s	remaining: 0us
# 0:	learn: 0.3984206	total: 1.63ms	remaining: 8.15s
# 500:	learn: 0.1047427	total: 765ms	remaining: 6.87s
# 1000:	learn: 0.0800204	total: 1.54s	remaining: 6.14s
# 1500:	learn: 0.0647037	total: 2.31s	remaining: 5.4s
# 2000:	learn: 0.0537459	total: 3.06s	remaining: 4.58s
# 2500:	learn: 0.0451253	total: 3.82s	remaining: 3.82s
# 3000:	learn: 0.0380796	total: 4.6s	remaining: 3.06s
# 3500:	learn: 0.0323193	total: 5.37s	remaining: 2.3s
# 4000:	learn: 0.0272046	total: 6.13s	remaining: 1.53s
# 4500:	learn: 0.0232407	total: 6.88s	remaining: 763ms
# 4999:	learn: 0.0200333	total: 7.64s	remaining: 0us
# 0:	learn: 0.4001280	total: 6.68ms	remaining: 33.4s
# 500:	learn: 0.1057837	total: 798ms	remaining: 7.17s
# 1000:	learn: 0.0815135	total: 1.59s	remaining: 6.36s
# 1500:	learn: 0.0671127	total: 2.34s	remaining: 5.46s
# 2000:	learn: 0.0565746	total: 3.19s	remaining: 4.78s
# 2500:	learn: 0.0481236	total: 3.94s	remaining: 3.94s
# 3000:	learn: 0.0405900	total: 4.72s	remaining: 3.14s
# 3500:	learn: 0.0341783	total: 5.51s	remaining: 2.36s
# 4000:	learn: 0.0292064	total: 6.33s	remaining: 1.58s
# 4500:	learn: 0.0251230	total: 7.13s	remaining: 791ms
# 4999:	learn: 0.0215977	total: 7.93s	remaining: 0us
# 0:	learn: 0.3891143	total: 1.69ms	remaining: 8.46s
# 500:	learn: 0.1040582	total: 778ms	remaining: 6.99s
# 1000:	learn: 0.0796781	total: 1.55s	remaining: 6.18s
# 1500:	learn: 0.0647340	total: 2.36s	remaining: 5.5s
# 2000:	learn: 0.0538234	total: 3.1s	remaining: 4.65s
# 2500:	learn: 0.0456955	total: 3.87s	remaining: 3.87s
# 3000:	learn: 0.0387211	total: 4.62s	remaining: 3.08s
# 3500:	learn: 0.0326551	total: 5.38s	remaining: 2.3s
# 4000:	learn: 0.0274486	total: 6.14s	remaining: 1.53s
# 4500:	learn: 0.0231834	total: 6.9s	remaining: 765ms
# 4999:	learn: 0.0200019	total: 7.69s	remaining: 0us
# 0:	learn: 0.3993056	total: 3.6ms	remaining: 18s
# 500:	learn: 0.1067113	total: 851ms	remaining: 7.64s
# 1000:	learn: 0.0810572	total: 1.62s	remaining: 6.49s
# 1500:	learn: 0.0658243	total: 2.38s	remaining: 5.55s
# 2000:	learn: 0.0545662	total: 3.13s	remaining: 4.68s
# 2500:	learn: 0.0457499	total: 3.88s	remaining: 3.87s
# 3000:	learn: 0.0386340	total: 4.7s	remaining: 3.13s
# 3500:	learn: 0.0328826	total: 5.44s	remaining: 2.33s
# 4000:	learn: 0.0281903	total: 6.19s	remaining: 1.55s
# 4500:	learn: 0.0240702	total: 6.94s	remaining: 770ms
# 4999:	learn: 0.0207728	total: 7.7s	remaining: 0us
# 0:	learn: 0.3992027	total: 2.35ms	remaining: 11.7s
# 500:	learn: 0.1041908	total: 801ms	remaining: 7.19s
# 1000:	learn: 0.0798585	total: 1.6s	remaining: 6.41s
# 1500:	learn: 0.0642279	total: 2.38s	remaining: 5.56s
# 2000:	learn: 0.0533812	total: 3.17s	remaining: 4.74s
# 2500:	learn: 0.0446722	total: 3.94s	remaining: 3.94s
# 3000:	learn: 0.0377731	total: 4.71s	remaining: 3.14s
# 3500:	learn: 0.0322518	total: 5.5s	remaining: 2.35s
# 4000:	learn: 0.0278252	total: 6.27s	remaining: 1.57s
# 4500:	learn: 0.0237243	total: 7.06s	remaining: 782ms
# 4999:	learn: 0.0203748	total: 7.85s	remaining: 0us
# 0:	learn: 0.4006318	total: 2.28ms	remaining: 11.4s
# 500:	learn: 0.1087198	total: 759ms	remaining: 6.81s
# 1000:	learn: 0.0827248	total: 1.56s	remaining: 6.23s
# 1500:	learn: 0.0667601	total: 2.31s	remaining: 5.39s
# 2000:	learn: 0.0557529	total: 3.06s	remaining: 4.58s
# 2500:	learn: 0.0466521	total: 3.83s	remaining: 3.83s
# 3000:	learn: 0.0393875	total: 4.6s	remaining: 3.06s
# 3500:	learn: 0.0331568	total: 5.38s	remaining: 2.3s
# 4000:	learn: 0.0281953	total: 6.14s	remaining: 1.53s
# 4500:	learn: 0.0241857	total: 6.97s	remaining: 772ms
# 4999:	learn: 0.0207572	total: 7.72s	remaining: 0us
# 💡 CatBoost CV RMSE: 0.12027971089058895

# %%
cat_model.fit(X, y)
# Out:
# 0:	learn: 0.3967110	total: 10.9ms	remaining: 54.4s
# 500:	learn: 0.1065860	total: 826ms	remaining: 7.41s
# 1000:	learn: 0.0820081	total: 1.59s	remaining: 6.37s
# 1500:	learn: 0.0670240	total: 2.43s	remaining: 5.67s
# 2000:	learn: 0.0567528	total: 3.38s	remaining: 5.07s
# 2500:	learn: 0.0480143	total: 4.16s	remaining: 4.16s
# 3000:	learn: 0.0412862	total: 4.95s	remaining: 3.3s
# 3500:	learn: 0.0353666	total: 5.74s	remaining: 2.46s
# 4000:	learn: 0.0302885	total: 6.51s	remaining: 1.63s
# 4500:	learn: 0.0263096	total: 7.3s	remaining: 809ms
# 4999:	learn: 0.0229336	total: 8.07s	remaining: 0us

# %%
preds = cat_model.predict(test)
final_preds = np.expm1(preds)

# %%
submission = pd.DataFrame({
    "Id": test_ID,
    "SalePrice": final_preds
})

submission.to_csv("catboost_submission.csv", index=False)
print("✅ Submission file created: catboost_submission.csv")
# Out:
# ✅ Submission file created: catboost_submission.csv
